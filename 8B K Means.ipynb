# %% [raw]
# K means is unsupervised algorithms an it tries to cluster data based on their similarities.
# In this, we are not atually trying to predict any sort of outcome, we are just trying to find patterns in the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# lets generate some artificial data

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4)

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
data[0].shape
# Out:
# (200, 2)

# %%
#           first colmn  sencond colmn data[1] has labels for clusters so uing it for colors.
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmodel = KMeans(n_clusters=4)

# %%
kmodel.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmodel.cluster_centers_
# Out:
# array([[ 4.44549685, -0.0205376 ],
#        [ 2.06721445, -9.71733226],
#        [-1.79043943,  4.25722932],
#        [ 3.34964939,  4.38294624]])

# %%
kmodel.labels_
# Out:
# array([1, 3, 1, 3, 0, 2, 3, 3, 1, 1, 2, 3, 1, 2, 2, 0, 2, 2, 0, 1, 0, 0,
#        0, 0, 3, 3, 3, 1, 0, 0, 2, 0, 1, 1, 2, 3, 0, 0, 3, 0, 0, 1, 3, 2,
#        1, 2, 1, 0, 1, 2, 3, 3, 0, 2, 1, 2, 3, 2, 3, 3, 3, 3, 2, 0, 1, 0,
#        2, 1, 1, 2, 3, 3, 0, 2, 2, 2, 2, 2, 2, 2, 3, 1, 1, 3, 3, 0, 3, 1,
#        1, 0, 1, 0, 2, 0, 3, 3, 1, 1, 1, 1, 3, 2, 0, 3, 0, 0, 3, 0, 3, 2,
#        2, 2, 1, 1, 1, 3, 2, 2, 2, 0, 2, 3, 2, 1, 3, 0, 1, 1, 0, 0, 2, 0,
#        0, 1, 0, 0, 2, 1, 0, 0, 1, 3, 0, 2, 1, 0, 0, 0, 0, 3, 3, 3, 3, 1,
#        2, 2, 0, 0, 1, 3, 1, 0, 3, 1, 1, 3, 2, 1, 2, 3, 2, 2, 0, 1, 2, 0,
#        3, 1, 0, 3, 0, 1, 0, 2, 1, 1, 3, 2, 1, 2, 2, 2, 3, 1, 0, 2, 3, 1,
#        0, 3])

# %%
plt.subplot(1, 2, 1)
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

plt.subplot(1, 2, 2)
plt.scatter(data[0][:,0],data[0][:,1],c=kmodel.labels_,cmap='rainbow')
